# %%
from openalea.plantgl.all import *
from openalea.mtg.aml import *

from openalea.groalea.convert_mtg import mtg2graph
from openalea.groalea.topology import RootedGraph
from openalea import groalea
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-fc255361c356> in <module>()
# ----> 1 from openalea.plantgl.all import *
#       2 from openalea.mtg.aml import *
#       3
#       4 from openalea.groalea.convert_mtg import mtg2graph
#       5 from openalea.groalea.topology import RootedGraph
#
# /home/long/.local/lib/python2.7/site-packages/VPlants.PlantGL-2.19.0-py2.7-linux-x86_64.egg/openalea/plantgl/__init__.py in <module>()
# ----> 1 import math
#       2 import scenegraph
#       3 import algo
#       4 from scenegraph import PGL_VERSION_STR,PGL_VERSION,PGL_SVNREVISION
#       5
#
# /home/long/.local/lib/python2.7/site-packages/VPlants.PlantGL-2.19.0-py2.7-linux-x86_64.egg/openalea/plantgl/math/__init__.py in <module>()
# ----> 1 from _pglmath import *
#       2
#
# ...

# %%
# %gui qt

# %%
from openalea.deploy import shared_data
data_dir = shared_data.shared_data(groalea, share_path='test/MappleT_docs')
data_dir
# Out:
# path(u'/home/long/python_ws/groalea/test/MappleT_docs')

# %%
mtg_fn = data_dir/'genotype_1.0_FdS.mtg'
scene_fn = data_dir/'1.0.bgeom'

rootedgraph = mtg2graph(str(mtg_fn), str(scene_fn))
from pprint import pprint
pprint (vars(rootedgraph))
# Out:
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# 0.00032761 0.0181 0.0181
# 1.0
# ...

# %%
from openalea.groalea.graphio import graph2xml

# %%
xeg = graph2xml(rootedgraph)
print xeg
# Out:
# <graph>
# 	<root root_id="3">
# 	</root>
# 	<type name="">
# 	</type>
# 	<node id="3" name="M1" type="F">
# 	<property name="transform">
# 	<matrix>
# 			1.00000 0.00000 0.00000 0.00000
# 			0.00000 1.00000 0.00000 0.00000
# 			0.00000 0.00000 1.00000 0.00000
# 			0.00000 0.00000 0.00000 1.00000
#
# </matrix>
# 	</property>
# 	<property name="length" value="0.181">
# 	</property>
# 	<property name="radius" value="0.0519308501922">
# 	</property>
# 	</node>
# 	<node id="4" name="M2" type="F">
# 	<property name="transform">
# 	<matrix>
# 			1.00000 0.00000 0.00000 0.00000
# 			0.00000 1.00000 0.00000 0.00000
# 			0.00000 0.00000 1.00000 0.00000
# 			0.00000 0.00000 0.00000 1.00000
#
# </matrix>
# 	</property>
# 	<property name="length" value="0.181">
# 	</property>
# 	<property name="radius" value="0.0519308501922">
# 	</property>
# 	</node>
# 	<node id="5" name="M3" type="F">
# 	<property name="transform">
# 	<matrix>
# 			1.00000 0.00000 0.00000 0.00000
# ...

# %%
from openalea.groalea.graphio import xml2graph, graph2xml
g, scene = xml2graph(xeg)
Viewer.display(scene)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-9-9659098f6863> in <module>()
#       1 from openalea.groalea.graphio import xml2graph, graph2xml
# ----> 2 g, scene = xml2graph(xeg)
#       3 Viewer.display(scene)
#
# /home/long/python_ws/groalea/groalea/graphio.pyc in xml2graph(xml_graph)
#     875     f = StringIO(xml_graph)
#     876     parser = Parser()
# --> 877     g, scene = parser.parse(f)
#     878     f.close()
#     879     return g, scene
#
# /home/long/python_ws/groalea/groalea/graphio.pyc in parse(self, fn)
#      75
#      76         self.dispatch(root)
# ---> 77         self.scenegraph()
#      78
#      79         return self._graph, self._scene
#
# /home/long/python_ws/groalea/groalea/graphio.pyc in scenegraph(self)
#     615         transfos = [pgl.Matrix4()]
#     616
# --> 617         self.traverse2(g.root)
# ...
