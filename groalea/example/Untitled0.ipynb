# %%
from openalea.groalea.convert_mtg import mtg2graph
from openalea.groalea.topology import RootedGraph
from openalea.plantgl.all import *
from openalea.mtg.aml import *
from openalea.plantgl.all import Viewer

# %%
#%gui qt

# %%
rootedgraph = mtg2graph("/home/long/python_ws/groalea/test/MappleT_docs/genotype_1.0_FdS.mtg", "/home/long/python_ws/groalea/test/MappleT_docs/1.0.bgeom")
# Out:
# Args  0.0000 of vertex  0 of type  year is not of type  <type 'int'>
# Args  0.0000 of vertex  1 of type  year is not of type  <type 'int'>
# Args  0.0181 of vertex  2 of type  year is not of type  <type 'int'>
# Args  trunk of vertex  2 of type  length is not of type  <type 'float'>
# Args  scar of vertex  2 of type  leaf_area is not of type  <type 'float'>
# Args  0.0000 of vertex  2 of type  unit_id is not of type  <type 'int'>
# Args  None of vertex  2 of type  radius is not of type  <type 'float'>
# Args  0.0362 of vertex  3 of type  year is not of type  <type 'int'>
# Args  trunk of vertex  3 of type  length is not of type  <type 'float'>
# Args  scar of vertex  3 of type  leaf_area is not of type  <type 'float'>
# Args  0.0000 of vertex  3 of type  unit_id is not of type  <type 'int'>
# Args  None of vertex  3 of type  radius is not of type  <type 'float'>
# Args  0.0543 of vertex  4 of type  year is not of type  <type 'int'>
# ...

# %%
from pprint import pprint
pprint (vars(rootedgraph))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-51904fecf254> in <module>()
#       1 from pprint import pprint
# ----> 2 pprint (vars(rootedgraph))
#
# NameError: name 'rootedgraph' is not defined
